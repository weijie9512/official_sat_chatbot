# %%
import pandas as pd

# %%
df = pd.read_csv("data/empatheticPersonas.csv")

# %%
df2 = df.iloc[:][['Sad - Patient response 1', 'Sad - Patient response 2', 'Sad - Patient response 3', 'Angry - Patient response 1', 'Angry - Patient response 2',
       'Angry - Patient response 3','Anxious - Patient response 1', 'Anxious - Patient response 2',
       'Anxious - Patient response 3','Happy - Patient response 1', 'Happy - Patient response 2',
       'Happy - Patient response 3']]

# %%
df2
# Out:
#                               Sad - Patient response 1  \
# 0                              I am feeling a bit down
# 1     I don't feel that great today. My dog is unwell.
# 2                Not very well, my dog died yesterday.
# 3                             I'm feeling kind of down
# 4    Not so good as I have been watching the news c...
# ..                                                 ...
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
#
#                               Sad - Patient response 2  \
# 0                             I'm in a pretty low mood
# 1    I feel a little sad. I am worried about losing...
# 2     Not great, just been feeling depressed all week.
# 3               I'm really sad because my dog ran away
# ...

# %%
df2.to_excel("feeling.xlsx")

# %%
df_sad = df.iloc[:][['Sad - Patient response 1', 'Sad - Patient response 2', 'Sad - Patient response 3']]
df_anxious = df.iloc[:][['Anxious - Patient response 1', 'Anxious - Patient response 2',
       'Anxious - Patient response 3']]
df_angry = df.iloc[:][['Angry - Patient response 1', 'Angry - Patient response 2', 'Angry - Patient response 3']]
df_happy = df.iloc[:][['Happy - Patient response 1', 'Happy - Patient response 2', 'Happy - Patient response 3']]

# %%
#df_anxious.to_excel("feeling_anxious.xlsx")

# %% [markdown]
# ## Label data
