# %%
import sys
    # caution: path[0] is reserved for script path (or '' in REPL)
sys.path.insert(1, '/Users/weijiechua/Desktop/ImperialClasses/Courses/Term3/wj_SATbot2.0')

# %%
# 1 for Lisa's version of fluency and novelty
# 2 for my version of fluency and novelty
version = 2

# %%
import pandas as pd
import numpy as np

# %%
from model import classifiers
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/weijiechua/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /Users/weijiechua/opt/anaconda3/envs/sat_chatbot/lib/python3.8/site-packages/transformers/models/t5/tokenization_t5.py:164: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-small automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.bias', 'vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/weijiechua/Desktop/ImperialClasses/Courses/Term3/wj_SATbot2.0
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/weijiechua/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = pd.read_excel("../data/survey_data/combined_data/sat_data_combined.xlsx", index_col=0)

# %%
df
# Out:
#                                        A01  \
# 0.0                       How do you feel?
# 1.0                   How are you feeling?
# 2.0             How are you feeling today?
# 3.0                     How are you doing?
# 4.0         How are you feeling right now?
# 5.0               How are you doing today?
# 6.0                       How do you feel?
# 7.0                       How do you feel?
# 8.0                   Do you feel alright?
# 9.0               How are you feeling now?
# 10.0  May I know how you're feeling today?
# 11.0        How are you feeling right now?
# 12.0          Is everything okay with you?
# NaN                                    NaN
# NaN                                    NaN
# NaN                                    NaN
# NaN                                    NaN
# NaN                                    NaN
# NaN                                    NaN
# NaN                                    NaN
# NaN                                    NaN
# NaN                                    NaN
# NaN                                    NaN
# NaN                                    NaN
#
#                                                     A02  \
# 0.0     Can I know if the predicted emotion is correct?
# 1.0                   Is the predicted emotion correct?
# 2.0   What do you think about the results? Do you th...
# 3.0                    Did I predict the right emotion?
# 4.0                 Did I guess your emotion correctly?
# 5.0                  Was the predicted emotion correct?
# 6.0   Would you say that's an accurate prediction of...
# 7.0     Do you think this is how you feel at this time?
# 8.0               Are you feeling what I am describing?
# 9.0   May I ask if you think the predicted emotion i...
# 10.0  Am I right to say that you're feeling the foll...
# 11.0  Could you tell me if the emotion I predicted i...
# 12.0              Is the predicted emotion is accurate?
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
#
#                                                     A03  \
# 0.0                Is the emotion positive or negative?
# 1.0              Do you feel more positive or negative?
# 2.0   Do you think that you are feeling more positiv...
# 3.0                            Do you feel good or bad?
# 4.0               Are you feeling positive or negative?
# 5.0    Is the emotion a positive one or a negative one?
# 6.0   Would you say the emotion is positive or negat...
# 7.0                Is the emotion positive or negative?
# 8.0             Are your emotions positive or negative?
# 9.0                Is the emotion positive or negative?
# 10.0  Would you say the emotion is positive or negat...
# 11.0    Do you feel that in a positive or negative way?
# 12.0  Can you tell if the emotion is positive or neg...
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
#
#                                                     A04  \
# 0.0   Let us practice Exercise 9 to overcome negativ...
# 1.0   Let us start practicing Exercise 9 to overcome...
# 2.0   Now, let's take a moment to go through Exercis...
# 3.0            Let's try Exercise 9 to see if it helps!
# 4.0   Let’s do Exercise 9 together to get over the n...
# 5.0   Let’s go through Exercise 9 so we can solve th...
# 6.0   Let's practice Exercise 9 to learn ways of ove...
# 7.0   Let us go through Exercise 9 to help you cope ...
# 8.0   Please complete Exercise 9 and we can get past...
# 9.0   Would you like to practice Exercise 9? This ex...
# 10.0  I think you should try Exercise 9, it will be ...
# 11.0  We will practice Exercise 9 together now to he...
# 12.0  For overcoming negative emotions, let us pract...
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
#
#                                

# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
#
#                                                     A10  ...  \
# 0.0   Now it is time for you to use your compassion ...  ...
# 1.0   Now it is time to use compassion energy meanin...  ...
# 2.0   Why don't we put your compassion skills to goo...  ...
# 3.0   Time to use your compassion for good in the re...  ...
# 4.0   Time to use your compassion energy to do meani...  ...
# 5.0   It’s time for you to apply what you’ve learnt ...  ...
# 6.0   Now it is time to generalise your compassion i...  ...
# 7.0   Now it is time for you to use your compassion ...  ...
# 8.0   Let's be compassionate and do meaningful thing...  ...
# 9.0   Cool! Are you ready to use your compassion ene...  ...
# 10.0  It is now time for you to spread your compassi...  ...
# 11.0  It is time for you to use your compassion to t...  ...
# 12.0  Now is the time to put your compassion energy ...  ...
# NaN                                                 NaN  ...
# NaN                                                 NaN  ...
# NaN                                                 NaN  ...
# NaN                                                 NaN  ...
# NaN                                                 NaN  ...
# NaN                                                 NaN  ...
# NaN                                                 NaN  ...
# NaN                                                 NaN  ...
# NaN                                                 NaN  ...
# NaN                                                 NaN  ...
# NaN                                                 NaN  ...
#
#                                                     I01  \
# 0.0       Have you research through existing solutions?
# 1.0     Have you thought about some possible solutions?
# 2.0   Have you researched through the existing solut...
# 3.0    Did you research for solutions that exist today?
# 4.0            Have you investigated current solutions?
# 5.0     Have you researched through existing solutions?
# 6.0       Is there a solution that you have researched?
# 7.0   Have you conducted research into existing solu...
# 8.0                  Have you researched any solutions?
# 9.0          Have you researched on existing solutions?
# 10.0       Did you research solutions that exist today?
# 11.0           Have you investigated current solutions?
# 12.0    Have you researched through existing solutions?
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
#
#                                                     I02  \
# 0.0   It's okay. Please set a new deadline to yourse...
# 1.0   That's totally fine. Let's set a new deadline ...
# 2.0   That is alright. You may set a new deadline, a...
# 3.0   That is fine! However, please set a deadline, ...
# 4.0   It's alright, no hard feelings. Promise me to ...
# 5.0   That's fine. Please set a new deadline to your...
# 6.0   There's nothing to worry about. Set a new dead...
# 7.0   No problem. Do set a new deadline for yourself...
# 8.0   It's okay. Please set a new deadline to yourse...
# 9.0   That's fine. Please set a new deadline for you...
# 10.0  That is fine! However, please set a deadline, ...
# 11.0  It's alright, no hard feelings. Promise me to ...
# 12.0  That's fine. Please set a new deadline to your...
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
#
#                                                   I03  \
# 0.0              Is there a reasonably good solution?
# 1.0                  Are there any helpful solutions?
# 2.0              Is there a reasonably good solution?
# 3.0                       Is there a decent solution?
# 4.0   Is there a better method to resolve this issue?
# 5.0            Is there any reasonably good solution?
# 6.0               Are there any reasonable solutions?
# 7.0            Does a reasonably good solution exist?
# 8.0                       Is there any good solution?
# 9.0                         Is there a good solution?
# 10.0                      Is there a decent solution?
# 11.0    Is there a good method to resolve this issue?
# 12.0           Is there any reasonably good solution?
# NaN                                               NaN
# NaN                                               NaN
# NaN                                               NaN
# NaN                                               NaN
# NaN                                               NaN
# NaN                                               NaN
# NaN                                               NaN
# NaN                                               NaN
# NaN                                               NaN
# NaN                                               NaN
# NaN                                               NaN
#
#                                                     I04  \
# 0.0   Think about how do you plan to achieve this. W...
# 1.0   Think carefully about how you can achieve your...
# 2.0   Visualise how you plan to achieve this. When d...
# 3.0   Think about a plan on how you can achieve this...
# 4.0   Coordinate a plan on how you are going to acco...
# 5.0   Think about how do you plan to achieve this go...
# 6.0   Plan how you will accomplish this. Consider th...
# 7.0   Reflect on how you might achieve this. While r...
# 8.0   Think about how do you plan to achieve this go...
# 9.0   Think about how you plan to achieve this. When...
# 10.0  Think about a plan on how you can achieve this...
# 11.0  Coordinate a plan on how you are going to acco...
# 12.0  Think about how do you plan to achieve this go...
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
#
#                                                    J01  \
# 0.0           Have you followed through your solution?
# 1.0             Did you follow through with your plan?
# 2.0      Have you followed through with your solution?
# 3.0   Did you commit and follow through your solution?
# 4.0   Have you pursued your idea to resolve the issue?
# 5.0           Have you followed through your solution?
# 6.0                Is your solution being implemented?
# 7.0        Have you followed through on your solution?
# 8.0         Have you followed through your solution?\n
# 9.0      Have you followed through with your solution?
# 10.0  Did you commit and follow through your solution?
# 11.0   Have you pursue your idea to resolve the issue?
# 12.0          Have you followed through your solution?
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
#
#                                                     J02  \
# 0.0   Try to reflect on what went wrong in the secon...
# 1.0   Think about why it might have gone differently...
# 2.0   Try to think back and reflect on what might ha...
# 3.0                What went wrong in the second stage?
# 4.0   Go ahead and reflect what could possibly be wr...
# 5.0   Could you please try to reflect on what went w...
# 6.0   Think back to the second stage and try to figu...
# 7.0    Reflect on the shortcomings in the second stage.
# 8.0                    What went wrong in second stage?
# 9.0     Reflect on what went wrong in the second stage.
# 10.0               What went wrong in the second stage?
# 11.0  Go ahead and reflect what could possibly be wr...
# 12.0  Could you please try to reflect on what went w...
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
#
#                                                     J03  \
# 0.0   Please find a partner that can complete the so...
# 1.0   It is important to find a partner that you can...
# 2.0   You can find a partner to complete the solutio...
# 3.0   You can start looking for a partner that can c...
# 4.0   Try to find a mate that can go through the sol...
# 5.0   Please find a partner who can complete the sol...
# 6.0   Find a partner who can complete the solution w...
# 7.0   Do partner with somebody who can see through t...
# 8.0   You are encouraged to find a partner that can ...
# 9.0   Find a partner that can complete the solution ...
# 10.0  You can start looking for a partner that can c...
# 11.0  Try to find a mate that can go through the sol...
# 12.0  Please find a partner who can complete the sol...
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
#
#                                                     J04  \
# 0.0   What do you feel about your compassion energy?...
# 1.0   What are your thoughts on your compassion energy?
# 2.0   What do you feel about your compassion energy?...
# 3.0   What is your feeling towards compassion energy...
# 4.0   IS there any special feeling you have develope...
# 5.0   What do you feel about your compassion energy?...
# 6.0   How do you feel about your compassion energy? ...
# 7.0   What are your feelings on compassion energy? J...
# 8.0   What do you feel about your compassion energy?...
# 9.0       How do you feel about your compassion energy?
# 10.0  What is your feeling towards compassion energy...
# 11.0  Is there any special feeling you have develope...
# 12.0  What do you feel about your compassion energy?...
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
#
#                                                     J05  \
# 0.0   Write down a blog post sharing your success st...
# 1.0   Share about your experience and thoughts on yo...
# 2.0   Write down a blog post sharing your success st...
# 3.0   Let us write down a blog post discussing your ...
# 4.0   Make a blog post recording your success story....
# 5.0   You can write a blog post sharing your success...
# 6.0   Share your success story in a blog post. Talk ...
# 7.0   Write a blog post detailing your story of succ...
# 8.0   Write down a blog post sharing your success st...
# 9.0   Write a blog post sharing your success story. ...
# 10.0  Let us write down a blog post discussing your ...
# 11.0  Make a blog post recording your success story....
# 12.0  You can write a blog post sharing your success...
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
#
#                                                     K01
# 0.0   Thank you for your cooperation today, I apprec...
# 1.0   Thank you so much for your time and cooperatio...
# 2.0   Thanks so much for talking with me, I really h...
# 3.0            Thank you for today. See you again soon.
# 4.0   I'm very grateful you took part and hopefully ...
# 5.0   Thank you so much for taking part in this sess...
# 6.0   I appreciate you for participating. We meet an...
# 7.0   Thank you for taking part, I really appreciate...
# 8.0   Thank you for today, I really appreciate it. C...
# 9.0   Thanks for your time today! Hope to hear from ...
# 10.0  I really appreciate the time that you have tak...
# 11.0  I really appreciate your effort, thank you for...
# 12.0  Let's end here for today, thank you for talkin...
# NaN    Thank you for your patience today. See you soon!
# NaN   I would really like to take the time to thank ...
# NaN   Thank you so much for spening time with me on ...
# NaN   Thank you very much for your time and efforts....
# NaN   Thank you for you cooperation and taking part ...
# NaN     Thank you ever so much. I hope to see you soon.
# NaN   Im really pleased that you could participate. ...
# NaN   Thank you, you've been great and it's been a p...
# NaN   I am grateful for your participation. I hope t...
# NaN   Thanks, you were brilliant today. I hope I wil...
# NaN   Many thanks for your cooperation. I hope to se...
#
# [24 rows x 65 columns]

# %%
df = df[:10]

# %%
df_col = list(df['A01'].dropna().values)

# %%
df_col
# Out:
# ['How do you feel?',
#  'How are you feeling?',
#  'How are you feeling today?',
#  'How are you doing?',
#  'How are you feeling right now?',
#  'How are you doing today?',
#  'How do you feel?',
#  'How do you feel?',
#  'Do you feel alright?',
#  'How are you feeling now?',
#  "May I know how you're feeling today?"]

# %%
df_col
# Out:
# ['How do you feel?',
#  'How are you feeling?',
#  'How are you feeling today?',
#  'How are you doing?',
#  'How are you feeling right now?',
#  'How are you doing today?',
#  'How do you feel?',
#  'How do you feel?',
#  'Do you feel alright?',
#  'How are you feeling now?',
#  "May I know how you're feeling today?"]

# %%
A02 = df.loc[:, ['A02']].dropna()

# %%
A02.columns = ['sentences']

# %%
A02
# Out:
#                                               sentences
# 0.0     Can I know if the predicted emotion is correct?
# 1.0                   Is the predicted emotion correct?
# 2.0   What do you think about the results? Do you th...
# 3.0                    Did I predict the right emotion?
# 4.0                 Did I guess your emotion correctly?
# 5.0                  Was the predicted emotion correct?
# 6.0   Would you say that's an accurate prediction of...
# 7.0     Do you think this is how you feel at this time?
# 8.0               Are you feeling what I am describing?
# 9.0   May I ask if you think the predicted emotion i...
# 10.0  Am I right to say that you're feeling the foll...

# %%
df_col
# Out:
# ['How do you feel?',
#  'How are you feeling?',
#  'How are you feeling today?',
#  'How are you doing?',
#  'How are you feeling right now?',
#  'How are you doing today?',
#  'How do you feel?',
#  'How do you feel?',
#  'Do you feel alright?',
#  'How are you feeling now?',
#  "May I know how you're feeling today?"]

# %% [markdown]
# ## Use Classifiers

# %%
classifiers.compute_distances(df_col[0], A02)
# Out:
# [2.5, 2.5, 1.9375, 2.5, 2.5, 2.5, 2.125, 1.75, 2.3125, 2.3125, 2.5]

# %%
#classifiers.get_sentence_score(df_col[0], A02)

# %% [markdown]
# ## Full Code Simulation

# %%
curr_sentence = df_col[0]

# %%
prev_df = pd.DataFrame([curr_sentence],columns=['sentences'])

# %%
prev_df['score'] = 0

# %%
prev_df
# Out:
#           sentences  score
# 0  How do you feel?      0

# %%
df_columns = df.columns

# %%
full_empathy_list = []
full_fluency_list = []
full_novelty_list = []

for i, col in enumerate(df_columns):
    print("==============================Current column: {col}=======================================")
    possible_options = pd.DataFrame(df.loc[:, [col]].dropna())
    best_score = 0
    empathy_list = []
    fluency_list = []
    novelty_list = []
    for index, row in possible_options.iterrows():
        sentence = row.values[0]
        empathy = classifiers.empathy_score(sentence)
        fluency = classifiers.fluency_score(sentence, version)
        novelty = classifiers.novelty_score(sentence, prev_df, version)
        score = empathy + 0.75*fluency + 2*novelty
        
        empathy_list.append(empathy.item())
        fluency_list.append(fluency)
        novelty_list.append(novelty)
        #score = classifiers.get_sentence_score(sentence, prev_df)
        
        if score > best_score:
            best_sentence = sentence
            best_score = score
    print(f"Best sentence: {best_sentence}, {'{:.2f}'.format(best_score.cpu())}")
    best_score = best_score.detach().numpy()
    s2 = pd.DataFrame.from_records([{"sentences": best_sentence, "score": best_score}])
    prev_df = pd.concat([prev_df, s2], ignore_index=True)
    #prev_df = prev_df.append({"sentences": best_sentence}, ignore_index=True)
    
    full_empathy_list.append(empathy_list)
    full_fluency_list.append(fluency_list)
    full_novelty_list.append(novelty_list)
# Out:
# ==============================Current column: {col}=======================================
# Best sentence: How are you feeling right now?, 1.05
# ==============================Current column: {col}=======================================
# Best sentence: Am I right to say that you're feeling the following emotion?, 1.81
# ==============================Current column: {col}=======================================
# Best sentence: Do you think that you are feeling more positively or negatively?, 1.45
# ==============================Current column: {col}=======================================
# Best sentence: Now, let's take a moment to go through Exercise 9 so that I can help you better understand how to overcome any negative feelings that you might be experiencing., 2.10
# ==============================Current column: {col}=======================================
# Best sentence: Do you feel like you are compassionate towards your childhood self?, 1.54
# ==============================Current column: {col}=======================================
# Best sentence: Great job! Do you feel like you want to protect your childhood self, or do you think it will be better to help your childhood self to grow up and face difficulties?, 2.31
# ==============================Current column: {col}=======================================
# Best sentence: Congratulations! You have displayed traits of tender compassion, which is the first phase of compassion! It means that you are able to sympathise with the victim, and hope to help them escape from their current predicament and alleviate their suffering., 2.52
# ==============================Current column: {col}=======================================
# Best sentence: Congratulations! You have displayed traits of foresighted compassion! It means that you are thinking about how you can help the victim in the long run. This is different from tender compassion where you only sympathise with the victim in the present/immediate form., 2.68
# ==============================Current column: {col}=======================================
# Best sentence: Let's take a step further to develop ourselves. Don't forget to go through the SAT module to strengthen your foresighted compassion skills. The great thing about foresighted compassion is that it's a more efficient, long-term solution that will help improve the lives of victims over the long run., 2.86
# ==============================Current column: {col}=======================================
# Best sentence: Why don't we put your compassion skills to good use? At the MAIN NODE, please navigate to Awareness, Understanding, Commitments (AUC) to begin your journey in improving the lives of the people around us!, 2.92
# ==============================Current column: {col}=======================================
# Best sentence: As a quick note before we begin, this chatbot exercise is meant for us to help you in your journey to becoming a more conscious and compassionate human!, 2.35
# ==============================Current column: {col}=======================================
# Best sentence: You understand that there are 2 types of compassion? Tender compassion is more common, where we simply feel sorry towards people suffering from unfortunate events. Meanwhile, foresighted goes beyond that by us wanting to make a difference to help the victims. Need an example?, 3.14
# ==============================Current column: {col}=======================================
# Best sentence: Don't worry, we're here to help! We'll be with you every step of the way in your compassion journey. Let's get started!, 2.90
# ==============================Current column: {col}=======================================
# Best sentence: Are you feeling closer emotionally to your childhood self now?, 1.60
# ==============================Current column: {col}=======================================
# Best sentence: Amazing! You have accomplished the first goal! However, we are still not exactly there. Are you ready to take your relationship with your childhood self to the next level?, 2.98
# ==============================Current column: {col}=======================================
# Best sentence: Let's do a quick check-in. How are we doing? Would you like to proceed with ESA or come back to it another time?, 2.75
# ==============================Current column: {col}=======================================
# Best sentence: I'm proud of you! You've managed to form a deeper connection with the child. In the next exercises 3, 4, and 5, you'll be able to give your childhood self some love through music, expressions of love, care and support., 3.21
# ==============================Current column: {col}=======================================
# Best sentence: Are you filled with love? Do you feel a stronger need to protect your childhood self?, 1.94
# ==============================Current column: {col}=======================================
# Best sentence: Well done! You have shown tender compassion, the first stage of compassion. This means you are now able to show sympathy towards your childhood self. Let's now extend this further and see what we can do with your new found compassion!, 3.18
# ==============================Current column: {col}=======================================
# Best sentence: May I ask you to practice exercises 1 and 2 please? To feel compassionate towards the childhood self, we have to first be intimate with our childhood self., 2.89
# ==============================Current column: {col}=======================================
# Best sentence: Which best describes the type of compassion you have towards your childhood self? Would you describe it as tender compassion, which is a more direct and immediate response of sympathy, or foresighted compassion, which focuses on a long-term solution for the child?, 2.76
# ==============================Current column: {col}=======================================
# Best sentence: Nice beginning! By developing compassion inside you, you are already a step ahead of others! Do not stop, we should try more SAT protocols to further nurture our compassion state., 3.03
# ==============================Current column: {col}=======================================
# Best sentence: It seems you are having tender compassion towards the childhood self. Now, translate that compassion of yours and project that feeling towards a less fortunate community. Slowly close your eyes and think about that community (If you need ideas, go to AUC)., 3.25
# ==============================Current column: {col}=======================================
# Best sentence: Do you feel an urge to lend a helping hand to these people?, 1.94
# ==============================Current column: {col}=======================================
# Best sentence: Why do you think you feel this way? Are you struggling to understand their difficulties, or do you believe that they are not worthy of help?, 3.06
# ==============================Current column: {col}=======================================
# Best sentence: Let's take a moment to reflect and deepen our relationship with our childhood self., 2.45
# ==============================Current column: {col}=======================================
# Best sentence: Wait a moment and start to think back. Now that you have nurtured a soft compassion towards your childhood self, let us do exercise 15 (to switch our outlook)., 3.02
# ==============================Current column: {col}=======================================
# Best sentence: Now close your eyes, and imagine that you're part of that vulnerable community. Feel the pain. Feel the worries. Do you feel that you deserve some help?, 3.02
# ==============================Current column: {col}=======================================
# Best sentence: There must have been an issue such as poverty that has led those people to their circumstance today. Try to picture the situations that other people have to live in. Now, do you feel that your feelings have changed? Do you want to help them?, 3.32
# ==============================Current column: {col}=======================================
# Best sentence: Now stop your imagination and transition back to your own self. Would you still think you might help the unfortunate group?, 2.72
# ==============================Current column: {col}=======================================
# Best sentence: Great! If you believe that you have shown the traits of foresighted compassion, is it okay if you still do some protocols to see how are we doing?, 3.02
# ==============================Current column: {col}=======================================
# Best sentence: Let us do Exercise 8. This is really helpful!, 1.57
# ==============================Current column: {col}=======================================
# Best sentence: If you could help them, how would you do it?, 1.83
# ==============================Current column: {col}=======================================
# Best sentence: Nice job! You have displayed foresighted compassion. This is where you expect the child to deal with the situation maturely and this shows that you have the capability to develop long-term sustainable solutions.  Let us move to MAIN NODE to make meaningful actions., 3.28
# ==============================Current column: {col}=======================================
# Best sentence: Now think about this. Sometimes children make unreasonable requests. When they don't get it, they will be upset. It is the responsibility of our adult self to teach them to bear with it, and deal with the situation with maturity. Let us practice exercises 17 and 18 (Identifying personal resentments and committing to constructive actions), 3.38
# ==============================Current column: {col}=======================================
# Best sentence: Do you think that the best solution is something that comes to mind immediately as it is something the child wants? Or do you think that the situation calls for a more complicated solution that requires discipline and/or maturity?, 3.28
# ==============================Current column: {col}=======================================
# Best sentence: I congratulate you! Your foresighted compassion has been demonstrated by you. The time has come to put it into practice! Make your way to AUC so that you can make a difference! Head to MAIN NODE., 3.24
# ==============================Current column: {col}=======================================
# Best sentence: It is likely some form of anti-social behaviour is being exhibited. Let us dive a little bit deeper., 2.64
# ==============================Current column: {col}=======================================
# Best sentence: Is there anyone in your life that you feel some sort of resentment towards?, 2.50
# ==============================Current column: {col}=======================================
# Best sentence: Do you care about things that are happening the people around you (e.g., your friends and family)?, 2.65
# ==============================Current column: {col}=======================================
# Best sentence: Are you aware of the happenings in your local community? Have you joined any local activities?, 2.01
# ==============================Current column: {col}=======================================
# Best sentence: Is it important to you what is happening on the other side of the world?, 2.67
# ==============================Current column: {col}=======================================
# Best sentence: Excellent! Do you feel compassion when discussing events that are occurring in other parts of the world?, 2.56
# ==============================Current column: {col}=======================================
# Best sentence: You've done a great job so far! Now let us go back to the question about vulnerable communities. , 2.62
# ==============================Current column: {col}=======================================
# Best sentence: There are several degrees to anti-social behavior. Let us dive deeper into the issue by acting them out. Proceed to exercises 17 and 18 (Identifying personal resentments and designing constructive actions), 3.04
# ==============================Current column: {col}=======================================
# Best sentence: Do you feel that you care more about environments around you, at least a little bit more now?
# , 2.65
# ==============================Current column: {col}=======================================
# Best sentence: We have agreed towards fulfilling last week's exercises, did you pursue them? How do you feel in terms of your own compassion trait?, 2.78
# ==============================Current column: {col}=======================================
# Best sentence: Let's begin - please select a new category from the following options., 1.71
# ==============================Current column: {col}=======================================
# Best sentence: After reading the story, how does it make you feel?, 1.30
# ==============================Current column: {col}=======================================
# Best sentence: Do you feel anything? Feeling nothing is also an answer. Why do you think you feel so?, 2.52
# ==============================Current column: {col}=======================================
# Best sentence: Perhaps your underlying compassion trait has not been fully stimulated. If you are willing to, let us practice some more SAT protocols to further discover this trait of yours., 2.95
# ==============================Current column: {col}=======================================
# Best sentence: If you feel bad for the unfortunate, and feel that you want to help that person with a more short term solutions, this shows that you have shown tender compassion towards the victim! It is a good start that you want to help them!, 3.17
# ==============================Current column: {col}=======================================
# Best sentence: Let us do a quick test. Which of the following solutions do you think is a form of foresighted compassion for climate change?, 1.82
# ==============================Current column: {col}=======================================
# Best sentence: That's a great start! But we can do more by thinking of a more scalable and sustainable solution. Reducing electricity and plastic bag usage are good initiatives, but the impact it makes is rather small. This is a type of tender compassion as its impact is minimal. On the other hand, larger-scale actions such as encouraging governments to support green-energy initiatives will have a much larger impact as a whole. This type of foresighted compassion requires deeper thought to solve issues on a more global level., 3.12
# ==============================Current column: {col}=======================================
# Best sentence: Congratulations on being compassionate! Now that you are clear on the difference between tender compassion and foresighted compassion, try to think and research how you can solve the problem that you have in mind with foresighted compassion. Come back in a week., 3.21
# ==============================Current column: {col}=======================================
# Best sentence: Is there a solution that you have researched?, 1.03
# ==============================Current column: {col}=======================================
# Best sentence: It's alright, no hard feelings. Promise me to set a new deadline and let's meet again next time., 2.63
# ==============================Current column: {col}=======================================
# Best sentence: Is there a better method to resolve this issue?, 1.23
# ==============================Current column: {col}=======================================
# Best sentence: Coordinate a plan on how you are going to accomplish this. When thinking about that plan, you may ponder upon the long-term consequence that is always shifting (Foresighted compassion needs well-thought and viable solutions). Take your pen and draft that plan., 3.15
# ==============================Current column: {col}=======================================
# Best sentence: Have you pursued your idea to resolve the issue?, 1.09
# ==============================Current column: {col}=======================================
# Best sentence: Try to think back and reflect on what might have possibly went wrong in the second stage., 2.59
# ==============================Current column: {col}=======================================
# Best sentence: It is important to find a partner that you can go through this journey with, so that you can hold each other accountable. Get started as soon as today., 3.09
# ==============================Current column: {col}=======================================
# Best sentence: What do you feel about your compassion energy? I very much look forward to your answer., 2.50
# ==============================Current column: {col}=======================================
# Best sentence: Let us write down a blog post discussing your success story. Discuss your ideas, actions, commitments, what you learn from, and your general feeling about compassion energy. And share them to the forum so that others can learn about it!, 3.15
# ==============================Current column: {col}=======================================
# Best sentence: Thank you so much for your time and cooperation today, I hope you enjoyed our session. I look forward to seeing you next time., 3.10

# %%
prev_df
# Out:
#                                             sentences      score
# 0                                    How do you feel?          0
# 1                      How are you feeling right now?  1.0500774
# 2   Am I right to say that you're feeling the foll...   1.810255
# 3   Do you think that you are feeling more positiv...  1.4455113
# 4   Now, let's take a moment to go through Exercis...  2.0996132
# ..                                                ...        ...
# 61  Try to think back and reflect on what might ha...  2.5897913
# 62  It is important to find a partner that you can...  3.0893521
# 63  What do you feel about your compassion energy?...   2.500877
# 64  Let us write down a blog post discussing your ...  3.1541896
# 65  Thank you so much for your time and cooperatio...  3.0958388
#
# [66 rows x 2 columns]

# %%
full_fluency_list
# Out:
# [[0.6903996903507459,
#   0.7897417562424308,
#   0.7917825711932326,
#   0.8566766913875938,
#   1.000103352061745,
#   0.8191226043861906,
#   0.6903996903507459,
#   0.6903996903507459,
#   0.5021698093210873,
#   0.7529043059486485,
#   0.5606055028028326],
#  [0.46550285656461027,
#   0.44892455489223665,
#   0.551018136738925,
#   0.4658729430957991,
#   0.4488785215117259,
#   0.44959043041612207,
#   0.6099160651926978,
#   0.6920088852024129,
#   0.5559375605766286,
#   0.48218849733724894,
#   0.5203401717528493],
#  [0.49111425990431495,
#   0.5258791301651828,
#   0.5406817759464213,
#   0.5288110210903187,
#   0.514554034221117,
#   0.569207167653974,
#   0.5943264574378841,
#   0.49111425990431495,
#   0.5115010744884563,
#   0.49312209994887934,
#   0.49363515253031126,
#   0.5157415465950526,
#   0.5068179096753853,
#   0.5399572364666128,
#   0.5017527329961267,
#   0.5579338676000386,
#   0.5184419115743355,
#   0.49363515253031126],
#  [0.5009291112184759,
#   0.4831984689269024,
#   0.5009291112184759,
#   0.4202810999658703,
#   0.41996297629303614,
#   0.534502748054977,
#   0.5838944857247038,
#   0.4454571616036377,
#   0.448873955312941,
#   0.49427171047746643,
#   0.4202810999658703],
#  [0.441036443019038,
#   0.5180906815269231,
#   0.4377320439110077,
#   0.4455861310480171,
#   0.4960640690581318,
#   0.5126313266152459,
#   0.47403612511047355,
#   0.5167252190341083,
#   0.441036443019038,
#   0.45138135821112246,
#   0.4455861310480171],
#  [0.6706657588522767,
#   0.874451550805809,
#   0.6240790875763009,
#   0.6345098198606566,
#   0.5639492536115486,
#   0.9428780476228825,
#   0.48653773896417235,
#   0.7504826481701675,
#   0.5906297788699008,
#   0.8564280268063886,
#   0.7397271949603929]]

# %%
full_novelty_list
# Out:
# [[0.0, 0.15, 0.15, 0.15, 0.15, 0.15, 0.0, 0.0, 0.13, 0.15, 0.17],
#  [0.22, 0.21, 0.18, 0.21, 0.22, 0.21, 0.19, 0.18, 0.2, 0.21, 0.21],
#  [0.22, 0.21, 0.27, 0.21, 0.21, 0.27, 0.26, 0.22, 0.23, 0.22, 0.26],
#  [0.3, 0.31, 0.3, 0.3, 0.31, 0.32, 0.32, 0.3, 0.32, 0.31, 0.31],
#  [0.27, 0.31, 0.27, 0.27, 0.27, 0.32, 0.32, 0.27, 0.23, 0.27, 0.31],
#  [0.45, 0.45, 0.45, 0.38, 0.38, 0.45, 0.4, 0.44, 0.39, 0.42, 0.43],
#  [0.56, 0.56, 0.56, 0.51, 0.54, 0.56, 0.56, 0.56, 0.56, 0.56, 0.56],
#  [0.67, 0.59, 0.67, 0.67, 0.58, 0.61, 0.64, 0.62, 0.66, 0.56, 0.67],
#  [0.77, 0.71, 0.77, 0.72, 0.65, 0.77, 0.77, 0.77, 0.74, 0.65, 0.72],
#  [0.82, 0.69, 0.77, 0.65, 0.69, 0.72, 0.79, 0.82, 0.62, 0.8, 0.81],
#  [0.48, 0.46, 0.72, 0.51, 0.41, 0.48, 0.48, 0.48, 0.58, 0.43, 0.46],
#  [0.91, 0.91, 0.92, 0.92, 0.9, 0.92, 0.92, 0.91, 0.91, 0.91, 0.92],
#  [0.64, 0.64, 0.64, 0.46, 0.55, 0.57, 0.62, 0.64, 0.65, 0.38, 0.5],
#  [0.36, 0.35, 0.3, 0.3, 0.3, 0.34, 0.36, 0.36, 0.36, 0.41, 0.42],
#  [0.77, 0.79, 0.91, 0.78, 0.61, 0.72, 0.76, 0.76, 0.54, 0.69, 0.77],
#  [0.35, 0.35, 0.66, 0.35, 0.31, 0.45, 0.35, 0.35, 0.35, 0.48, 0.48],
#  [0.91, 0.92, 0.9, 0.87, 0.69, 0.88, 0.92, 0.91, 0.77, 0.77, 0.92],
#  [0.47, 0.42, 0.51, 0.49, 0.45, 0.47, 0.48, 0.47, 0.47, 0.39, 0.74],
#  [0.4, 0.49, 0.4, 0.4, 0.71, 0.38, 0.59, 0.56, 0.44, 0.44, 0.4],
#  [0.38, 0.37, 0.38, 0.37, 0.41, 0.41, 0.36, 0.41, 0.38, 0.26, 0.37],
#  [0.31, 0.26, 0.31, 0.26, 0.38, 0.31, 0.38, 0.26, 0.36, 0.26, 0.26],
#  [0.23, 0.25, 0.31, 0.23, 0.36, 0.4, 0.36, 0.44, 0.58, 0.23, 0.23],
#  [0.74, 0.56, 0.72, 0.69, 0.81, 0.67, 0.74, 0.7, 0.76, 0.6, 0.69],
#  [0.92, 0.89, 0.92, 0.86, 0.81, 0.93, 0.87, 0.88, 0.9, 0.76, 0.85],
#  [0.67, 0.52, 0.67, 0.56, 0.71, 0.71, 0.65, 0.71, 0.67, 0.62, 0.56],
#  [0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95],
#  [0.94, 0.87, 0.92, 0.93, 0.94, 0.94, 0.9, 0.94, 0.94, 0.91, 0.93],
#  [0.24, 0.26, 0.26, 0.32, 0.23, 0.24, 0.31, 0.26, 0.23, 0.24, 0.26],
#  [0.45, 0.5, 0.44, 0.5, 0.61, 0.45, 0.56, 0.48, 0.45, 0.48, 0.5],
#  [0.24, 0.24, 0.24, 0.24, 0.36, 0.25, 0.24, 0.25, 0.24, 0.23, 0.24],
#  [0.85, 0.79, 0.83, 0.81, 0.92, 0.89, 0.77, 0.81, 0.9, 0.79, 0.81],
#  [0.24, 0.26, 0.26, 0.31, 0.36, 0.24, 0.24, 0.26, 0.24, 0.26, 0.31],
#  [0.4, 0.55, 0.58, 0.26, 0.48, 0.5, 0.5, 0.32, 0.25, 0.37, 0.26],
#  [0.62, 0.8, 0.44, 0.75, 0.72, 0.58, 0.62, 0.72, 0.74, 0.6, 0.75],
#  [0.52, 0.32, 0.52, 0.44, 0.55, 0.55, 0.58, 0.41, 0.5, 0.31, 0.44],
#  [0.8, 0.7, 0.8, 0.91, 0.88, 0.87, 0.82, 0.79, 0.8, 0.72, 0.91],
#  [0.44, 0.72, 0.67, 0.32, 0.48, 0.62, 0.37, 0.62, 0.45, 0.4, 0.74]]

# %%
type(full_empathy_list[0])
# Out:
# list

# %%
full_empathy_list_np = np.array(full_empathy_list)
full_fluency_list_np = np.array(full_fluency_list)
full_novelty_list_np = np.array(full_novelty_list)

# %%
np.max(full_empathy_list_np)
# Out:
# 1.0

# %%
np.max(full_empathy_list_np)
# Out:
# 1.0

# %%
np.max(full_novelty_list_np)
# Out:
# 1.0

# %%
#full_empathy_list_np

# %%
np.max(full_fluency_list_np, axis=1)
# Out:
# array([1.00010335, 0.69200889, 0.59432646, 0.66615084, 0.52971451,
#        0.57908462, 0.53572652, 0.46324942, 0.43619303, 0.50154054,
#        0.67719961, 0.45424117, 0.83006189, 0.57498381, 0.61010509,
#        0.57368426, 0.55025458, 0.56610387, 0.52087225, 0.52848596,
#        0.46922747, 0.51447045, 0.39175178, 0.67154553, 0.69975792,
#        0.6273722 , 0.48385933, 0.65413787, 0.56033091, 0.58906137,
#        0.53714443, 0.53242053, 0.78497062, 0.5306858 , 0.53419948,
#        0.54583137, 0.49436516, 0.68175594, 0.67153733, 0.65454109,
#        0.70793397, 0.86221581, 0.61254922, 0.55644777, 0.52408191,
#        0.68539243, 0.64789395, 0.53916754, 0.71513508, 0.72247344,
#        0.50187906, 0.5422052 , 0.53203651, 0.29770346, 0.47694066,
#        0.54907847, 0.65318837, 0.68080931, 0.52813019, 0.60759449,
#        0.68889567, 0.65246952, 0.58389449, 0.51809068, 0.94287805])

# %%
np.min(full_fluency_list_np, axis=1)
# Out:
# array([0.50216981, 0.44887852, 0.49111426, 0.45445476, 0.48098785,
#        0.40266907, 0.32321362, 0.26657873, 0.13845447, 0.39895517,
#        0.50796999, 0.15036222, 0.47450381, 0.47928384, 0.51514523,
#        0.45137533, 0.33590153, 0.46387459, 0.37980233, 0.27006031,
#        0.36969958, 0.43447709, 0.2939751 , 0.51698526, 0.56628083,
#        0.50128596, 0.40707762, 0.52837976, 0.45273053, 0.48121647,
#        0.47130828, 0.45048514, 0.57361586, 0.44634869, 0.43946979,
#        0.40119605, 0.43427026, 0.48281558, 0.46682804, 0.54338464,
#        0.47947102, 0.46825084, 0.45899832, 0.47648095, 0.44181648,
#        0.47665535, 0.47440308, 0.45921635, 0.48827569, 0.48465952,
#        0.37290356, 0.399271  , 0.43031402, 0.0337865 , 0.32572807,
#        0.45017133, 0.48094549, 0.46707363, 0.33093373, 0.45582475,
#        0.47746977, 0.4931221 , 0.41996298, 0.43773204, 0.48653774])

# %%
full_fluency_list_np_diff = np.max(full_fluency_list_np, axis=1) - np.min(full_fluency_list_np, axis=1)

# %%
full_fluency_list_np_diff
# Out:
# array([0.49793354, 0.24313036, 0.1032122 , 0.21169607, 0.04872666,
#        0.17641554, 0.2125129 , 0.19667069, 0.29773856, 0.10258537,
#        0.16922962, 0.30387895, 0.35555808, 0.09569997, 0.09495985,
#        0.12230893, 0.21435305, 0.10222928, 0.14106992, 0.25842565,
#        0.0995279 , 0.07999336, 0.09777668, 0.15456027, 0.13347709,
#        0.12608624, 0.07678171, 0.12575811, 0.10760038, 0.1078449 ,
#        0.06583615, 0.08193539, 0.21135476, 0.08433711, 0.09472969,
#        0.14463531, 0.0600949 , 0.19894036, 0.2047093 , 0.11115646,
#        0.22846295, 0.39396497, 0.1535509 , 0.07996682, 0.08226543,
#        0.20873708, 0.17349087, 0.07995119, 0.22685939, 0.23781393,
#        0.12897549, 0.1429342 , 0.1017225 , 0.26391697, 0.15121259,
#        0.09890714, 0.17224289, 0.21373568, 0.19719646, 0.15176974,
#        0.2114259 , 0.15934742, 0.16393151, 0.08035864, 0.45634031])

# %%
full_empathy_list_np_diff = np.max(full_empathy_list_np, axis=1) - np.min(full_empathy_list_np, axis=1)
full_fluency_list_np_diff = np.max(full_fluency_list_np, axis=1) - np.min(full_fluency_list_np, axis=1)
full_novelty_list_np_diff = np.max(full_novelty_list_np, axis=1) - np.min(full_novelty_list_np, axis=1)

# %%
df_graph = pd.DataFrame({"empathy": full_empathy_list_np_diff, "fluency": full_fluency_list_np_diff, "novelty": full_novelty_list_np_diff})

# %%
df_graph.columns = ["empathy", "fluency", "novelty"]

# %%
df_graph
# Out:
#     empathy   fluency  novelty
# 0       0.0  0.497934     0.17
# 1       1.0  0.243130     0.04
# 2       0.5  0.103212     0.06
# 3       1.0  0.211696     0.02
# 4       0.5  0.048727     0.09
# ..      ...       ...      ...
# 60      1.0  0.211426     0.33
# 61      1.0  0.159347     0.36
# 62      1.0  0.163932     0.27
# 63      1.0  0.080359     0.21
# 64      1.0  0.456340     0.42
#
# [65 rows x 3 columns]

# %%
df_graph["empathy_weight"] = 1
df_graph["fluency_weight"] = 1
df_graph["novelty_weight"] = 1

# %%
df_graph["empathy_total"] = df_graph["empathy"] * df_graph["empathy_weight"]
df_graph["fluency_total"] = df_graph["fluency"] * df_graph["fluency_weight"]
df_graph["novelty_total"] = df_graph["novelty"] * df_graph["novelty_weight"]

# %%
df_graph2 = df_graph[["empathy_total", "fluency_total", "novelty_total"]]

# %%
df_new_graph = pd.DataFrame(df_graph2.unstack())

# %%
df_new_graph = df_new_graph.reset_index()

# %%
df_new_graph.columns = ["type", "utterances", "score"]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ax = sns.lineplot(data=df_new_graph, x="utterances", y="score", hue="type")
ax.set(xlabel='Sequence of utterances', ylabel='Difference in scores per node')
plt.show()

# %% [markdown]
# # Mark the average

# %%
full_list = []
for i in range(len(full_empathy_list)):
    avg_empathy = sum(full_empathy_list[i])/len(full_empathy_list[i])
    avg_fluency = sum(full_fluency_list[i])/len(full_fluency_list[i])
    avg_novelty = sum(full_novelty_list[i])/len(full_novelty_list[i])
    avg_total = avg_empathy + avg_fluency + avg_novelty
    temp_list = [avg_empathy, avg_fluency, avg_novelty, avg_total]
    full_list.append(temp_list)

full_list

df_graph = pd.DataFrame(full_list)

df_graph.columns = ["empathy", "fluency", "novelty", "total"]

df_graph.drop(columns="total", inplace=True)

df_graph
# Out:
#      empathy   fluency   novelty
# 0   0.000000  0.740391  0.109091
# 1   0.272727  0.517289  0.203636
# 2   0.045455  0.532057  0.234545
# 3   0.454545  0.500683  0.309091
# 4   0.181818  0.498259  0.282727
# ..       ...       ...       ...
# 60  0.363636  0.547923  0.406364
# 61  0.363636  0.525411  0.667273
# 62  0.545455  0.477507  0.467273
# 63  0.363636  0.470901  0.818182
# 64  0.772727  0.703122  0.530000
#
# [65 rows x 3 columns]

# %%
df_graph["empathy_weight"] = 1
df_graph["fluency_weight"] = 1
df_graph["novelty_weight"] = 1.5

df_graph["empathy_total"] = df_graph["empathy"] * df_graph["empathy_weight"]
df_graph["fluency_total"] = df_graph["fluency"] * df_graph["fluency_weight"]
df_graph["novelty_total"] = df_graph["novelty"] * df_graph["novelty_weight"]

df_graph2 = df_graph[["empathy_total", "fluency_total", "novelty_total"]]

df_new_graph = pd.DataFrame(df_graph2.unstack())

df_new_graph = df_new_graph.reset_index()

df_new_graph.columns = ["type", "utterances", "score"]

# %%
ax = sns.lineplot(data=df_new_graph, x="utterances", y="score", hue="type")
ax.set(xlabel='Sequence of utterances', ylabel='Average scores')
plt.show()
