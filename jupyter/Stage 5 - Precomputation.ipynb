# %%
import sys  
sys.path.insert(0, '/Users/weijiechua/Desktop/ImperialClasses/Courses/thirdterm/individual/official/official_sat_chatbot/model')

# %%
import pandas as pd

# %%
df = pd.read_excel("../data/survey_data/combined_data/sat_data_combined.xlsx", index_col=0)

# %%
df
# Out:
#                                        A01  \
# 0.0                       How do you feel?
# 1.0                   How are you feeling?
# 2.0             How are you feeling today?
# 3.0                     How are you doing?
# 4.0         How are you feeling right now?
# 5.0               How are you doing today?
# 6.0                       How do you feel?
# 7.0                       How do you feel?
# 8.0                   Do you feel alright?
# 9.0               How are you feeling now?
# 10.0  May I know how you're feeling today?
# 11.0        How are you feeling right now?
# 12.0          Is everything okay with you?
# NaN                                    NaN
# NaN                                    NaN
# NaN                                    NaN
# NaN                                    NaN
# NaN                                    NaN
# NaN                                    NaN
# NaN                                    NaN
# NaN                                    NaN
# ...

# %%
import classifiers
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/weijiechua/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 import classifiers
#
# File ~/Desktop/ImperialClasses/Courses/thirdterm/individual/official/official_sat_chatbot/model/classifiers.py:63, in <module>
#      61 #load emotion classifier (T5 small)
#      62 with torch.no_grad():
# ---> 63     emo_model = T5FineTuner(args)
#      64     try:
#      65       emo_model.load_state_dict(torch.load('T5_small_emotion.pt', map_location=torch.device('cpu')), strict=False)
#
# File ~/Desktop/ImperialClasses/Courses/thirdterm/individual/official/official_sat_chatbot/model/classifiers.py:37, in T5FineTuner.__init__(self, hparams)
#      35 def __init__(self, hparams):
# ...

# %%
# %%capture
#!pip install Flask-SQLAlchemy
# !pip install textdistance
