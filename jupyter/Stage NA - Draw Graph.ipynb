# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Draw graph of sentence representation and 3 classifiers

# %%
df = pd.read_excel("../data/result/experiments result.xlsx", sheet_name="SSL")

# %%
df = df.iloc[3:]

# %%
df
# Out:
#     No Dataset          SSL Model        Model Train/Test  Train  Accuracy  \
# 3    4   Myown  bert-base-uncased        Logit      30:70     30        72
# 4    5   Myown  bert-base-uncased      XGBoost      30:70     30        77
# 5    6   Myown  bert-base-uncased  Naïve Bayes      30:70     30        64
# 6    7   Myown  bert-base-uncased        Logit      10,90     10        66
# 7    8   Myown  bert-base-uncased      XGBoost      10,90     10        68
# 8    9   Myown  bert-base-uncased  Naïve Bayes      10,90     10        63
# 9   10   Myown  bert-base-uncased        Logit      20,80     20        71
# 10  11   Myown  bert-base-uncased      XGBoost      20,80     20        73
# 11  12   Myown  bert-base-uncased  Naïve Bayes      20,80     20        64
# 12  13    Lisa  bert-base-uncased        Logit      30:70     30        68
# 13  14    Lisa  bert-base-uncased      XGBoost      30:70     30        63
# 14  15    Lisa  bert-base-uncased  Naïve Bayes      30:70     30        58
# 15  16    Lisa  bert-base-uncased        Logit      20,80     20        63
# 16  17    Lisa  bert-base-uncased      XGBoost      20,80     20        60
# 17  18    Lisa  bert-base-uncased  Naïve Bayes      20,80     20        56
# 18  19    Lisa  bert-base-uncased        Logit      10,90     10        60
# 19  20    Lisa  bert-base-uncased      XGBoost      10,91     10        56
# 20  21    Lisa  bert-base-uncased  Naïve Bayes      10,92     10        54
#
#     F1 Screenshot
# 3   71       ssl4
# 4   76       ssl5
# 5   63       ssl6
# 6   65       ssl7
# 7   66       ssl8
# 8   61       ssl9
# 9   70      ssl10
# 10  71      ssl11
# 11  63      ssl12
# 12  68      ssl13
# 13  63      ssl14
# 14  57      ssl15
# 15  64      ssl16
# 16  60      ssl17
# 17  56      ssl18
# 18  60      ssl19
# 19  56      ssl20
# 20  54      ssl21

# %%
df2 = df[df['Dataset'] == "Myown"]

# %%
ax = sns.lineplot(data=df2, x="Train", y="Accuracy", hue="Model")
ax.set(xlabel='Training set proportion of whole dataset', ylabel='Accuracy')

plt.show()

# %%
df3 = df[df['Dataset'] == "Lisa"]

# %%
ax = sns.lineplot(data=df3, x="Train", y="Accuracy", hue="Model")
ax.set(xlabel='Training set proportion of whole dataset', ylabel='Accuracy')

plt.show()

# %% [markdown]
# ## Draw graph of response time

# %%
df = pd.read_excel("../data/result/experiments result.xlsx", sheet_name="Empathy Inference Time")

# %%
df
# Out:
#     No                    Model  Data ratio  Data size  Time spent
# 0    1        bert-base-uncased        0.01         24      0.1885
# 1    2        bert-base-uncased        0.10        237      1.3470
# 2    3        bert-base-uncased        0.15        356      3.7100
# 3    4        bert-base-uncased        0.20        474      4.8900
# 4    5        bert-base-uncased        0.25        592      6.0305
# 5    6        bert-base-uncased        0.30        711      7.3770
# 6    7        bert-base-uncased        0.40        948      9.8300
# 7    8        bert-base-uncased        0.50       1184     12.3830
# 8    9  distilbert-base-uncased        0.01         24      0.1486
# 9   10  distilbert-base-uncased        0.10        237      0.6820
# 10  11  distilbert-base-uncased        0.15        356      1.6296
# 11  12  distilbert-base-uncased        0.20        474      2.1160
# 12  13  distilbert-base-uncased        0.25        592      2.6669
# 13  14  distilbert-base-uncased        0.30        711      3.1938
# 14  15  distilbert-base-uncased        0.40        948      4.2398
# 15  16  distilbert-base-uncased        0.50       1184      5.2459

# %%
sns.lineplot(data=df, x="Data size", y="Time spent", hue="Model")
# Out:
# <AxesSubplot:xlabel='Data size', ylabel='Time spent'>
